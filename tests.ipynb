# %%
import pandas as pd
import openml
from preprocessing import split, check_feature_sample_ratio, delete_corr_columns, fill_na, assign_target_column, add_permuted_columns, drop_categorical
from evaluate import plot_our_history
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Breast Cancer

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler

data = load_breast_cancer()
X = StandardScaler().fit_transform(data.data)
y = data.target.astype(float)

plot_our_history(X, y, epochs=50, lam=1e-3)
# Out:
# Accuracy:
# Accelerated CD: 0.989
# CD: 0.986
# FISTA: 0.986
# Subgradient: 0.967
# F1 score:
# Accelerated CD: 0.992
# CD: 0.989
# FISTA: 0.989
# Subgradient: 0.973

# %% [markdown]
# # Arythmia

# %%
col_names = [f"attr{i}" for i in range(1, 280)]
df_arythmia = pd.read_csv("./data/arythmia/arrhythmia.data", header=None, names=col_names, na_values="?")
print(df_arythmia.head())
df_arythmia = df_arythmia.reset_index()
df_arythmia.columns = df_arythmia.columns.astype(str)
# Out:
#     attr1  attr2  attr3  attr4  attr5  attr6  attr7  attr8  attr9  attr10  \
# 75      0    190     80     91    193    371    174    121    -16    13.0
# 56      1    165     64     81    174    401    149     39     25    37.0
# 54      0    172     95    138    163    386    185    102     96    34.0
# 55      0    175     94    100    202    380    179    143     28    11.0
# 75      0    190     80     88    181    360    177    103    -16    13.0
#
#     ...  attr270  attr271  attr272  attr273  attr274  attr275  attr276  \
# 75  ...      0.0      9.0     -0.9      0.0      0.0      0.9      2.9
# 56  ...      0.0      8.5      0.0      0.0      0.0      0.2      2.1
# 54  ...      0.0      9.5     -2.4      0.0      0.0      0.3      3.4
# 55  ...      0.0     12.2     -2.2      0.0      0.0      0.4      2.6
# 75  ...      0.0     13.1     -3.6      0.0      0.0     -0.1      3.9
#
#     attr277  attr278  attr279
# 75     23.3     49.4        8
# 56     20.4     38.8        6
# 54     12.3     49.0       10
# 55     34.6     61.6        1
# 75     25.4     62.8        7
#
# [5 rows x 279 columns]

# %% [markdown]
# class 0 is normal, class 1 are different types of arythmia

# %%
assign_target_column(df_arythmia, "attr279", [i for i in range(2,16)])
fill_na(df_arythmia)
delete_corr_columns(df_arythmia)
check_feature_sample_ratio(df_arythmia)
# Out:
# Unique values of label column [ 8  6 10  1  7 14  3 16  2  4  5  9 15]
# target
# 0    267
# 1    185
# Name: count, dtype: int64
# attr10 8 null values
# attr11 22 null values
# attr12 1 null values
# attr13 376 null values
# attr14 1 null values
# deleted features: ['attr160', 'attr163', 'attr170', 'attr184', 'attr192', 'attr193', 'attr194', 'attr203', 'attr207', 'attr211', 'attr214', 'attr217', 'attr224', 'attr234', 'attr243', 'attr254', 'attr263', 'attr273']
# Shape after deletion (452, 262)
# The number of features is enough: True, number of features: 262

# %%
X = df_arythmia.drop(columns=['target'])
y = df_arythmia['target']
X = StandardScaler().fit_transform(X)
plot_our_history(X, y.values, epochs=150, lam=1e-3)
# Out:
# Accuracy:
# Accelerated CD: 0.956
# CD: 0.954
# FISTA: 0.954
# Subgradient: 0.865
# F1 score:
# Accelerated CD: 0.945
# CD: 0.942
# FISTA: 0.942
# Subgradient: 0.827

# %% [markdown]
# # Secom

# %%
df_data = pd.read_csv("./data/secom/secom.data", sep=' ', header=None, na_values="NaN")  
df_label = pd.read_csv("./data/secom/secom_labels.data",sep=' ', header=None, na_values="NaN")

df_label.columns = ["label", "timestamp"]
df_secom = pd.concat([df_data, df_label["label"]], axis=1)
print("Shape:", df_secom.shape)
df_secom.columns = df_secom.columns.astype(str)
# Out:
# Shape: (1567, 591)

# %%
assign_target_column(df_secom, "label", [1])
fill_na(df_secom)
delete_corr_columns(df_secom)
df_secom = add_permuted_columns(df_secom)
delete_corr_columns(df_secom)
check_feature_sample_ratio(df_secom)
# Out:
# Unique values of label column [-1  1]
# target
# 0    1463
# 1     104
# Name: count, dtype: int64
# 0 6 null values
# 1 7 null values
# 2 14 null values
# 3 14 null values
# 4 14 null values
# 5 14 null values
# 6 14 null values
# 7 9 null values
# 8 2 null values
# 9 2 null values
# 10 2 null values
# 11 2 null values
# 12 2 null values
# 13 3 null values
# 14 3 null values
# 15 3 null values
# 16 3 null values
# 17 3 null values
# 18 3 null values
# 19 10 null values
# 21 2 null values
# 22 2 null values
# 23 2 null values
# 24 2 null values
# 25 2 null values
# 26 2 null values
# 27 2 null values
# 28 2 null values
# 29 2 null values
# 30 2 null values
# 31 2 null values
# 32 1 null values
# 33 1 null values
# 34 1 null values
# 35 1 null values
# 36 1 null values
# 37 1 null values
# 38 1 null values
# 39 1 null values
# 40 24 null values
# 41 24 null values
# 42 1 null values
# 43 1 null values
# 44 1 null values
# 45 1 null values
# 46 1 null values
# 47 1 null values
# 48 1 null values
# 49 1 null values
# 50 1 null values
# 51 1 null values
# 52 1 null values
# 53 4 null values
# 54 4 null values
# 55 4 null values
# 56 4 null values
# 57 4 null values
# 58 4 null values
# 59 7 null values
# 60 6 null values
# 61 6 null values
# 62 6 null values
# 63 7 null values
# 64 7 null values
# 65 7 null values
# 66 6 null values
# 67 6 null values
# 68 6 null values
# 69 6 null values
# 70 6 null values
# 71 6 null values
# 72 794 null values
# 73 794 null values
# 74 6 null values
# 75 24 null values
# 76 24 null values
# 77 24 null values
# 78 24 null values
# 79 24 null values
# 80 24 null values
# 81 24 null values
# 82 24 null values
# 83 1 null values
# 84 12 null values
# 85 1341 null values
# 89 51 null values
# 90 51 null values
# 91 6 null values
# 92 2 null values
# 93 2 null values
# 94 6 null values
# 95 6 null values
# 96 6 null values
# 97 6 null values
# 98 6 null values
# 99 6 null values
# 100 6 null values
# 101 6 null values
# 102 6 null values
# 103 2 null values
# 104 2 null values
# 105 6 null values
# 106 6 null values
# 107 6 null values
# 108 6 null values
# 109 1018 null values
# 110 1018 null values
# 111 1018 null values
# 112 715 null values
# 118 24 null values
# 121 9 null values
# 122 9 null values
# 123 9 null values
# 124 9 null values
# 125 9 null values
# 126 9 null values
# 127 9 null values
# 128 9 null values
# 129 9 null values
# 130 9 null values
# 131 9 null values
# 132 8 null values
# 133 8 null values
# 134 8 null values
# 135 5 null values
# 136 6 null values
# 137 7 null values
# 138 14 null values
# 139 14 null values
# 140 14 null values
# 141 14 null values
# 142 14 null values
# 143 9 null values
# 144 2 null values
# 145 2 null values
# 146 2 null values
# 147 2 null values
# 148 2 null values
# 149 3 null values
# 150 3 null values
# 151 3 null values
# 152 3 null values
# 153 3 null values
# 154 3 null values
# 155 10 null values
# 157 1429 null values
# 158 1429 null values
# 159 2 null values
# 160 2 null values
# 161 2 null values
# 162 2 null values
# 163 2 null values
# 164 2 null values
# 165 2 null values
# 166 2 null values
# 167 2 null values
# 168 2 null values
# 169 2 null values
# 170 1 null values
# 171 1 null values
# 172 1 null values
# 173 1 null values
# 174 1 null values
# 175 1 null values
# 176 1 null values
# 177 1 null values
# 178 24 null values
# 179 1 null values
# 180 1 null values
# 181 1 null values
# 182 1 null values
# 183 1 null values
# 184 1 null values
# 185 1 null values
# 186 1 null values
# 187 1 null values
# 188 1 null values
# 189 1 null values
# 190 4 null values
# 191 4 null values
# 192 4 null values
# 193 4 null values
# 194 4 null values
# 195 4 null values
# 196 7 null values
# 197 6 null values
# 198 6 null values
# 199 6 null values
# 200 7 null values
# 201 7 null values
# 202 7 null values
# 203 6 null values
# 204 6 null values
# 205 6 null values
# 206 6 null values
# 207 6 null values
# 208 6 null values
# 209 6 null values
# 210 24 null values
# 211 24 null values
# 212 24 null values
# 213 24 null values
# 214 24 null values
# 215 24 null values
# 216 24 null values
# 217 24 null values
# 218 1 null values
# 219 12 null values
# 220 1341 null values
# 224 51 null values
# 225 51 null values
# 226 6 null values
# 227 2 null values
# 228 2 null values
# 229 6 null values
# 230 6 null values
# 231 6 null values
# 232 6 null values
# 233 6 null values
# 234 6 null values
# 235 6 null values
# 236 6 null values
# 237 6 null values
# 238 2 null values
# 239 2 null values
# 240 6 null values
# 241 6 null values
# 242 6 null values
# 243 6 null values
# 244 1018 null values
# 245 1018 null values
# 246 1018 null values
# 247 715 null values
# 253 24 null values
# 256 9 null values
# 257 9 null values
# 258 9 null values
# 259 9 null values
# 260 9 null values
# 261 9 null values
# 262 9 null values
# 263 9 null values
# 264 9 null values
# 265 9 null values
# 266 9 null values
# 267 8 null values
# 268 8 null values
# 269 8 null values
# 270 5 null values
# 271 6 null values
# 272 7 null values
# 273 14 null values
# 274 14 null values
# 275 14 null values
# 276 14 null values
# 277 14 null values
# 278 9 null values
# 279 2 null values
# 280 2 null values
# 281 2 null values
# 282 2 null values
# 283 2 null values
# 284 3 null values
# 285 3 null values
# 286 3 null values
# 287 3 null values
# 288 3 null values
# 289 3 null values
# 290 10 null values
# 292 1429 null values
# 293 1429 null values
# 294 2 null values
# 295 2 null values
# 296 2 null values
# 297 2 null values
# 298 2 null values
# 299 2 null values
# 300 2 null values
# 301 2 null values
# 302 2 null values
# 303 2 null values
# 304 2 null values
# 305 1 null values
# 306 1 null values
# 307 1 null values
# 308 1 null values
# 309 1 null values
# 310 1 null values
# 311 1 null values
# 312 1 null values
# 313 24 null values
# 314 24 null values
# 315 1 null values
# 316 1 null values
# 317 1 null values
# 318 1 null values
# 319 1 null values
# 320 1 null values
# 321 1 null values
# 322 1 null values
# 323 1 null values
# 324 1 null values
# 325 1 null values
# 326 4 null values
# 327 4 null values
# 328 4 null values
# 329 4 null values
# 330 4 null values
# 331 4 null values
# 332 7 null values
# 333 6 null values
# 334 6 null values
# 335 6 null values
# 336 7 null values
# 337 7 null values
# 338 7 null values
# 339 6 null values
# 340 6 null values
# 341 6 null values
# 342 6 null values
# 343 6 null values
# 344 6 null values
# 345 794 null values
# 346 794 null values
# 347 6 null values
# 348 24 null values
# 349 24 null values
# 350 24 null values
# 351 24 null values
# 352 24 null values
# 353 24 null values
# 354 24 null values
# 355 24 null values
# 356 1 null values
# 357 12 null values
# 358 1341 null values
# 362 51 null values
# 363 51 null values
# 364 6 null values
# 365 2 null values
# 366 2 null values
# 367 6 null values
# 368 6 null values
# 369 6 null values
# 370 6 null values
# 371 6 null values
# 372 6 null values
# 373 6 null values
# 374 6 null values
# 375 6 null values
# 376 2 null values
# 377 2 null values
# 378 6 null values
# 379 6 null values
# 380 6 null values
# 381 6 null values
# 382 1018 null values
# 383 1018 null values
# 384 1018 null values
# 385 715 null values
# 391 24 null values
# 394 9 null values
# 395 9 null values
# 396 9 null values
# 397 9 null values
# 398 9 null values
# 399 9 null values
# 400 9 null values
# 401 9 null values
# 402 9 null values
# 403 9 null values
# 404 9 null values
# 405 8 null values
# 406 8 null values
# 407 8 null values
# 408 5 null values
# 409 6 null values
# 410 7 null values
# 411 14 null values
# 412 14 null values
# 413 14 null values
# 414 14 null values
# 415 14 null values
# 416 9 null values
# 417 2 null values
# 418 2 null values
# 419 2 null values
# 420 2 null values
# 421 2 null values
# 422 3 null values
# 423 3 null values
# 424 3 null values
# 425 3 null values
# 426 3 null values
# 427 3 null values
# 428 10 null values
# 430 2 null values
# 431 2 null values
# 432 2 null values
# 433 2 null values
# 434 2 null values
# 435 2 null values
# 436 2 null values
# 437 2 null values
# 438 2 null values
# 439 2 null values
# 440 2 null values
# 441 1 null values
# 442 1 null values
# 443 1 null values
# 444 1 null values
# 445 1 null values
# 446 1 null values
# 447 1 null values
# 448 1 null values
# 449 24 null values
# 450 24 null values
# 451 1 null values
# 452 1 null values
# 453 1 null values
# 454 1 null values
# 455 1 null values
# 456 1 null values
# 457 1 null values
# 458 1 null values
# 459 1 null values
# 460 1 null values
# 461 1 null values
# 462 4 null values
# 463 4 null values
# 464 4 null values
# 465 4 null values
# 466 4 null values
# 467 4 null values
# 468 7 null values
# 469 6 null values
# 470 6 null values
# 471 6 null values
# 472 7 null values
# 473 7 null values
# 474 7 null values
# 475 6 null values
# 476 6 null values
# 477 6 null values
# 478 6 null values
# 479 6 null values
# 480 6 null values
# 481 6 null values
# 482 24 null values
# 483 24 null values
# 484 24 null values
# 485 24 null values
# 486 24 null values
# 487 24 null values
# 488 24 null values
# 489 24 null values
# 490 1 null values
# 491 12 null values
# 492 1341 null values
# 496 51 null values
# 497 51 null values
# 498 6 null values
# 499 2 null values
# 500 2 null values
# 501 6 null values
# 502 6 null values
# 503 6 null values
# 504 6 null values
# 505 6 null values
# 506 6 null values
# 507 6 null values
# 508 6 null values
# 509 6 null values
# 510 2 null values
# 511 2 null values
# 512 6 null values
# 513 6 null values
# 514 6 null values
# 515 6 null values
# 516 1018 null values
# 517 1018 null values
# 518 1018 null values
# 519 715 null values
# 525 24 null values
# 528 9 null values
# 529 9 null values
# 530 9 null values
# 531 9 null values
# 532 9 null values
# 533 9 null values
# 534 9 null values
# 535 9 null values
# 536 9 null values
# 537 9 null values
# 538 9 null values
# 539 8 null values
# 540 8 null values
# 541 8 null values
# 542 2 null values
# 543 2 null values
# 544 2 null values
# 545 2 null values
# 546 260 null values
# 547 260 null values
# 548 260 null values
# 549 260 null values
# 550 260 null values
# 551 260 null values
# 552 260 null values
# 553 260 null values
# 554 260 null values
# 555 260 null values
# 556 260 null values
# 557 260 null values
# 558 1 null values
# 559 1 null values
# 560 1 null values
# 561 1 null values
# 562 273 null values
# 563 273 null values
# 564 273 null values
# 565 273 null values
# 566 273 null values
# 567 273 null values
# 568 273 null values
# 569 273 null values
# 578 949 null values
# 579 949 null values
# 580 949 null values
# 581 949 null values
# 582 1 null values
# 583 1 null values
# 584 1 null values
# 585 1 null values
# 586 1 null values
# 587 1 null values
# 588 1 null values
# 589 1 null values
# deleted features: ['27', '36', '50', '54', '70', '96', '101', '104', '105', '106', '123', '127', '140', '148', '152', '154', '164', '165', '174', '199', '204', '206', '207', '209', '244', '245', '246', '249', '252', '270', '271', '272', '273', '274', '275', '277', '278', '279', '280', '281', '282', '283', '285', '286', '287', '288', '289', '290', '291', '292', '293', '294', '295', '296', '297', '298', '299', '300', '301', '302', '303', '304', '305', '306', '307', '308', '309', '310', '311', '312', '317', '318', '319', '320', '321', '323', '324', '331', '332', '333', '334', '335', '336', '337', '338', '339', '340', '341', '342', '343', '344', '346', '347', '348', '349', '350', '351', '352', '353', '354', '355', '356', '357', '359', '360', '361', '362', '363', '365', '366', '376', '377', '382', '383', '384', '386', '387', '388', '389', '390', '391', '392', '393', '405', '406', '407', '408', '409', '410', '411', '413', '415', '416', '417', '420', '421', '424', '425', '426', '427', '428', '429', '434', '435', '436', '437', '440', '441', '442', '443', '444', '445', '446', '447', '448', '452', '453', '454', '455', '456', '457', '459', '467', '469', '470', '471', '475', '477', '478', '479', '490', '491', '492', '493', '494', '495', '497', '516', '517', '518', '519', '520', '522', '523', '524', '525', '526', '527', '539', '540', '541', '545', '552', '553', '554', '556', '557', '561', '566', '567', '568', '569', '574', '575', '576', '577', '580', '584', '585', '588']
# Shape after deletion (1567, 381)
# Current num of features: 380, adding: 784 features
# New dataframe shape: (1567, 785)
# deleted features: []
# Shape after deletion (1567, 785)
# The number of features is enough: True, number of features: 785

# %%
X = df_secom.drop(columns=['target'])
y = df_secom['target']
X = StandardScaler().fit_transform(X)
plot_our_history(X, y.values, epochs=200, lam=1e-3)
# Out:
# Accuracy:
# Accelerated CD: 0.632
# CD: 0.631
# FISTA: 0.632
# Subgradient: 0.619
# F1 score:
# Accelerated CD: 0.263
# CD: 0.263
# FISTA: 0.263
# Subgradient: 0.255

# %% [markdown]
# # braidflow

# %%
pd.set_option('display.max_columns', None)

dataset = openml.datasets.get_dataset(45966)

df_braidflow, y, categorical, numeric = dataset.get_data(dataset_format='dataframe', target=dataset.default_target_attribute)

df_braidflow["label"] = y
print("Shape:", df_braidflow.shape)
print(df_braidflow.head(1))
df_braidflow["label"].value_counts()
# Out:
# Shape: (72, 124)
#    UID  task_id  action_absorption  action_accord  action_fluidity  care  \
# 0    1        5                  3              7                6     3
#
#    challenge_match  clear_mindedness  control  demand  \
# 0                4                 5        6       4
#
#    factor_absorption_by_activity  factor_fluency_of_performance  \
# 0                            3.5                       6.333333
#
#    factor_perceived_fit_of_skill_and_task_demands  \
# 0                                             5.0
#
#    factor_subjective_value_of_activity  focus  forward_thinking  fss_score  \
# 0                             2.333333      7                 7        5.2
#
#    loss_of_time_perception  lost_in_thought  perceived_difficulty  relevance  \
# 0                        6                1                     4          3
#
#    self_evaluation  worry task_braid  task_braid_revolutions  \
# 0                7      1     VBRAID                       6
#
#    task_braid_strands  braiding_statistics_duration  \
# 0                   4                    590.005509
#
#    braiding_statistics_revadvancework  braiding_statistics_revolutions  \
# 0                            0.031256                         0.027683
#
#    braiding_statistics_revundowork  braiding_statistics_revwork  \
# 0                        -0.000166                     0.031422
#
#    braiding_statistics_trials  disk_acc_mean_lateral  disk_acc_mean_medial  \
# 0                      0.1661                    NaN                   NaN
#
#    disk_acc_mean_overall  disk_acc_peaks_lateral  disk_acc_peaks_medial  \
# 0                    NaN                     NaN                    NaN
#
#    disk_acc_peaks_overall  disk_acc_std_lateral  disk_acc_std_medial  \
# 0                     NaN                   NaN                  NaN
#
#    disk_acc_std_overall  disk_speed_mean_lateral  disk_speed_mean_medial  \
# 0                   NaN                      NaN                     NaN
#
#    disk_speed_mean_overall  disk_flips  disk_heading_movements  \
# 0                      NaN         NaN                     NaN
#
#    disk_heading_rhythm_5  disk_heading_rhythm_10  disk_heading_rhythm_15  \
# 0                    NaN                     NaN                     NaN
#
#    disk_heading_rhythm_20  disk_heading_rhythm_25  disk_heading_rhythm_30  \
# 0                     NaN                     NaN                     NaN
#
#    disk_heading_rhythm_35  disk_heading_rhythm_40  disk_heading_rhythm_45  \
# 0                     NaN                     NaN                     NaN
#
#    disk_heading_rhythm_resonant_frequency  disk_heading_rhythm_resonant_score  \
# 0                                       5                                 NaN
#
#    wristband_acc_mean_lateral  wristband_acc_mean_medial  \
# 0                    0.006331                   0.011695
#
#    wristband_acc_mean_overall  wristband_acc_peaks_lateral  \
# 0                    0.014573                     0.178607
#
#    wristband_acc_peaks_medial  wristband_acc_peaks_overall  \
# 0                    0.118663                     0.101711
#
#    wristband_acc_std_lateral  wristband_acc_std_medial  \
# 0                   0.004935                  0.008984
#
#    wristband_acc_std_overall  wristband_speed_mean_lateral  \
# 0                   0.008339                      3.734786
#
#    wristband_speed_mean_medial  wristband_speed_mean_overall  \
# 0                     6.899227                      8.597054
#
#    heartrate_above_baseline  heartrate_below_baseline  heartrate_mean  \
# 0                  3.583987                 -3.584943       86.170965
#
#    heartrate_peaks_frequency  heartrate_range  heartrate_std  \
# 0                   0.005093         31.08321       8.357307
#
#    heartrate_valleys_frequency  skintemperature_above_baseline  \
# 0                     0.008489                        0.095225
#
#    skintemperature_below_baseline  skintemperature_mean  \
# 0                       -0.095179             31.028278
#
#    skintemperature_peaks_frequency  skintemperature_range  \
# 0                         0.050869               0.692201
#
#    skintemperature_std  skintemperature_valleys_frequency  \
# 0             0.209609                           0.040695
#
#    eda_phasic_peaks_frequency  eda_phasic_scr_amplitude_mean  \
# 0                    0.055956                       0.550979
#
#    eda_phasic_scr_amplitude_range  eda_phasic_scr_amplitude_std  \
# 0                         1.17786                      0.385738
#
#    eda_phasic_scr_recoverytime_mean  eda_phasic_scr_recoverytime_range  \
# 0                          0.165323                           0.390625
#
#    eda_phasic_scr_recoverytime_std  eda_phasic_scr_risetime_mean  \
# 0                         0.094651                      0.283617
#
#    eda_phasic_scr_risetime_range  eda_phasic_scr_risetime_std  \
# 0                        0.40625                     0.099427
#
#    eda_tonic_energy  eda_tonic_mean  eda_tonic_range  eda_tonic_std  \
# 0         12.802909        3.200694         1.444219       0.506268
#
#    emg_peaks_frequency  emg_scr_amplitude_mean  emg_scr_amplitude_range  \
# 0             0.132303              123.736274               412.878792
#
#    emg_scr_amplitude_std  emg_scr_recoverytime_mean  \
# 0             113.553187                   0.956055
#
#    emg_scr_recoverytime_range  emg_scr_recoverytime_std  \
# 0                      12.375                  1.791557
#
#    emg_scr_risetime_mean  emg_scr_risetime_range  emg_scr_risetime_std  \
# 0               0.604968                   4.625              0.573477
#
#    emg_tonic_energy  emg_tonic_mean  emg_tonic_range  emg_tonic_std  \
# 0       8148.261957      906.728823       182.006969      38.249398
#
#       timestamp    study paper_ref  age  gender  ethnicity dexterity  \
# 0  1.644418e+09  dataset        U7   29  female  caucasian     right
#
#    flow_deposition  needlecraft_engagement  needlecraft_proficiency  \
# 0              4.5                       4                      4.8
#
#    needlecraft_skill  needlecraft_work    label
# 0           4.433333              11.0  neutral
# label
# neutral    37
# fall       18
# flow       17
# Name: count, dtype: int64

# %%
assign_target_column(df_braidflow, "label", ["flow"])
df_braidflow = drop_categorical(df_braidflow)
fill_na(df_braidflow)
delete_corr_columns(df_braidflow)
check_feature_sample_ratio(df_braidflow)
# Out:
# Unique values of label column ['neutral' 'flow' 'fall']
# target
# 0    55
# 1    17
# Name: count, dtype: int64
# Number of columns to keep 118, to delete 6
# disk_acc_mean_lateral 6 null values
# disk_acc_mean_medial 6 null values
# disk_acc_mean_overall 6 null values
# disk_acc_peaks_lateral 6 null values
# disk_acc_peaks_medial 6 null values
# disk_acc_peaks_overall 6 null values
# disk_acc_std_lateral 6 null values
# disk_acc_std_medial 6 null values
# disk_acc_std_overall 6 null values
# disk_speed_mean_lateral 6 null values
# disk_speed_mean_medial 6 null values
# disk_speed_mean_overall 6 null values
# disk_flips 21 null values
# disk_heading_movements 6 null values
# disk_heading_rhythm_5 6 null values
# disk_heading_rhythm_10 6 null values
# disk_heading_rhythm_15 6 null values
# disk_heading_rhythm_20 6 null values
# disk_heading_rhythm_25 6 null values
# disk_heading_rhythm_30 6 null values
# disk_heading_rhythm_35 6 null values
# disk_heading_rhythm_40 6 null values
# disk_heading_rhythm_45 6 null values
# disk_heading_rhythm_resonant_score 6 null values
# deleted features: ['fss_score', 'task_braid_strands', 'braiding_statistics_revolutions', 'braiding_statistics_revwork', 'disk_acc_mean_overall', 'disk_acc_std_lateral', 'disk_acc_std_medial', 'disk_acc_std_overall', 'disk_speed_mean_overall', 'disk_heading_rhythm_10', 'disk_heading_rhythm_15', 'disk_heading_rhythm_20', 'disk_heading_rhythm_25', 'disk_heading_rhythm_30', 'disk_heading_rhythm_35', 'disk_heading_rhythm_40', 'disk_heading_rhythm_45', 'disk_heading_rhythm_resonant_score', 'wristband_acc_mean_overall', 'wristband_acc_std_overall', 'wristband_speed_mean_overall', 'heartrate_below_baseline', 'heartrate_range', 'heartrate_std', 'skintemperature_below_baseline', 'skintemperature_range', 'skintemperature_std', 'eda_phasic_scr_amplitude_range', 'eda_phasic_scr_amplitude_std', 'eda_phasic_scr_recoverytime_std', 'eda_tonic_mean', 'eda_tonic_std', 'emg_scr_amplitude_range', 'emg_scr_amplitude_std', 'emg_scr_recoverytime_std', 'emg_scr_risetime_std', 'emg_tonic_mean', 'emg_tonic_std', 'needlecraft_skill']
# Shape after deletion (72, 79)
# The number of features is enough: True, number of features: 79

# %%
X = df_braidflow.drop(columns=['target'])
y = df_braidflow['target']
X = StandardScaler().fit_transform(X)
plot_our_history(X, y.values, epochs=120, lam=1e-3)
# Out:
# Accuracy:
# Accelerated CD: 1.000
# CD: 1.000
# FISTA: 1.000
# Subgradient: 0.903
# F1 score:
# Accelerated CD: 1.000
# CD: 1.000
# FISTA: 1.000
# Subgradient: 0.829

# %% [markdown]
# # lsvt

# %% [markdown]
# speech signal processing

# %%
dataset = openml.datasets.get_dataset(1484)
df_lsvt, y, categorical, numeric = dataset.get_data(dataset_format='dataframe', target=dataset.default_target_attribute)

df_lsvt["label"] = y
print("Shape:", df_lsvt.shape)
print(df_lsvt.head(1))
df_lsvt["label"].value_counts()
# Out:
# Shape: (126, 311)
#          V1        V2       V3        V4        V5        V6        V7  \
# 0  0.088112  0.041697  0.00048 -0.000004  0.000422  2.458381  0.000001
#
#           V8          V9       V10       V11       V12       V13       V14  \
# 0  47.021079  1366.43039 -7.103323 -2.687924 -0.035674  2.849068  0.042287
#
#         V15       V16      V17       V18       V19      V20       V21  \
# 0  9.116401  0.000002  0.04192  0.000482  0.000004  0.00044  0.000055
#
#         V22  V23       V24  V25  V26  V27  V28       V29       V30       V31  \
# 0  0.000001  0.0  0.000001  0.0    0    0    0  0.042287  0.000204  0.069838
#
#          V32      V33       V34      V35      V36       V37      V38  \
# 0  11.566415  0.07716 -0.000064  0.08188  0.09207 -0.000057  0.08188
#
#         V39       V40      V41       V42       V43       V44       V45  \
# 0  0.100744  0.000057  0.08188  0.059512  1.012151  0.021821  0.076036
#
#         V46      V47       V48       V49       V50       V51        V52  \
# 0  0.099596 -0.13452 -0.057768 -0.002472  0.068937  0.359709  12.996102
#
#         V53       V54       V55  V56       V57  V58       V59       V60  \
# 0  1.256612  0.052206  0.014418  1.0  27.27604  0.0  0.530926  0.664873
#
#         V61       V62       V63       V64           V65       V66       V67  \
# 0  0.001055  0.947504  0.098227  0.168098  1.615286e+06  1.678331  3.054999
#
#        V68       V69        V70        V71        V72         V73       V74  \
# 0  0.00763  0.011541  14.370621  11.635927  11.142235  535.937072  1.186678
#
#         V75       V76       V77       V78       V79       V80       V81  \
# 0  5.725144  1.386944  2.049552  0.422025  2.621502  0.168538  7.170821
#
#         V82       V83       V84       V85       V86       V87       V88  \
# 0  0.169427  6.419479  7.673133  6.885523 -0.623816 -0.241969 -0.227525
#
#         V89       V90       V91       V92       V93       V94       V95  \
# 0 -1.434329 -1.075752  2.166025  1.065309 -0.835358 -0.625799 -0.048179
#
#         V96       V97       V98       V99      V100      V101      V102  \
# 0 -0.263441 -0.002778 -0.008799 -0.002025  0.005298 -0.000161 -0.001069
#
#        V103      V104      V105     V106      V107      V108      V109  \
# 0  0.000287  0.002001  0.001059 -0.00063  0.001382  0.000931 -0.001288
#
#        V110      V111      V112      V113      V114      V115      V116  \
# 0  0.001648 -0.000107  0.000104 -0.000179  0.000009 -0.000327  0.000426
#
#        V117      V118      V119      V120      V121      V122      V123  \
# 0  0.000091  0.000044 -0.000457  0.000024  0.000333  0.000022 -0.000023
#
#        V124       V125      V126      V127     V128       V129  V130  \
# 0 -0.000118  20.066401  2.863953  9.116401  88200.0  99.991892   0.0
#
#        V131      V132      V133      V134      V135      V136      V137  \
# 0  0.000007  0.000014  0.000081  0.000084  0.000392  0.000748  0.000253
#
#        V138      V139      V140       V141        V142         V143  \
# 0  0.001156  0.005373  0.277671 -68.078738 -105.424586 -1209.725599
#
#          V144         V145          V146         V147          V148  \
# 0 -978.179117 -6262.174583 -16321.283376 -5389.818593 -18206.620534
#
#             V149         V150         V151        V152      V153       V154  \
# 0 -138456.212676 -8901.797548 -2297.164786 -538.933783 -82.77399  12.369696
#
#         V155       V156       V157       V158       V159      V160      V161  \
# 0  38.294372  46.296323  20.850136  30.703709  38.612416  0.000207  0.125311
#
#        V162      V163      V164       V165        V166       V167        V168  \
# 0  0.342469  4.311457  8.387436  66.036075  236.871121  57.601336  533.857918
#
#           V169      V170      V171      V172       V173      V174        V175  \
# 0  1794.712582  0.002351  1.524386  2.185394  16.210434  19.79354  101.353691
#
#          V176        V177        V178         V179          V180  \
# 0  322.698575  147.035242  1021.09278  4162.827266 -1.025306e+09
#
#            V181          V182          V183          V184          V185  \
# 0 -1.103548e+09 -1.200440e+09 -1.336479e+09 -1.554411e+09 -1.943670e+09
#
#            V186          V187          V188          V189          V190  \
# 0 -2.648732e+09 -4.050382e+09 -6.900005e+09 -1.275972e+10  11479.315311
#
#           V191         V192         V193         V194        V195        V196  \
# 0  6179.220781  3362.473962  1873.353844  1091.015543  683.563274  466.547205
#
#          V197        V198        V199        V200        V201         V202  \
# 0  357.344831  304.823334  282.034833  167.366006  662.506551  2607.646541
#
#           V203          V204           V205           V206         V207  \
# 0  9852.397924  35514.969896  118888.669963  365490.176708  998596.9673
#
#            V208          V209         V210          V211          V212  \
# 0  2.447613e+06  5.519108e+06  3777.116603  10577.281956  29577.734045
#
#            V213           V214           V215          V216          V217  \
# 0  81902.916278  219402.627035  566730.501401  1.377764e+06  3.197755e+06
#
#            V218          V219       V220  V221  V222      V223      V224  \
# 0  7.029561e+06  1.491377e+07  99.999712   0.0   0.0  0.000001  0.000003
#
#        V225      V226      V227      V228      V229      V230      V231  \
# 0  0.000003  0.000014  0.000026  0.000009  0.000041  0.000191  0.000024
#
#        V232      V233      V234      V235      V236      V237      V238  \
# 0  0.005506  0.010413  0.048112  0.046818  0.163887  0.280273  0.112783
#
#       V239      V240          V241         V242       V243        V244  \
# 0  0.25797  0.680496 -14450.746212 -4866.811478 -1952.2847 -778.302344
#
#          V245        V246        V247        V248       V249       V250  V251  \
# 0 -342.079482 -204.368504 -124.872803 -128.140898 -97.108063 -57.607519   0.0
#
#        V252      V253      V254      V255      V256      V257      V258  \
# 0  0.000003  0.000008  0.000098  0.000194  0.001499  0.005376  0.001307
#
#        V259      V260  V261      V262      V263      V264      V265      V266  \
# 0  0.012238  0.041324   0.0  0.000038  0.000051  0.000366  0.000468  0.002346
#
#        V267     V268      V269      V270           V271           V272  \
# 0  0.007406  0.00341  0.023366  0.096115 -233661.124486 -277726.266517
#
#             V273           V274           V275           V276           V277  \
# 0 -327634.174384 -390417.424919 -481323.914068 -633245.644644 -901856.900985
#
#            V278          V279          V280         V281         V282  \
# 0 -1.433921e+06 -2.528416e+06 -4.819157e+06  4076.864063  2422.969509
#
#           V283       V284        V285        V286        V287        V288  \
# 0  1429.320757  851.74552  525.181116  345.610973  246.183529  195.776526
#
#          V289        V290      V291      V292      V293      V294       V295  \
# 0  172.652511  164.557388  0.112549  0.443874  1.728619  6.539524  23.606344
#
#         V296        V297        V298         V299         V300      V301  \
# 0  79.049121  242.544298  661.679929  1618.318338  3643.234312  2.527583
#
#        V302       V303       V304       V305        V306        V307  \
# 0  7.088978  19.753255  54.335046  145.52863  375.097397  921.296579
#
#           V308         V309         V310 label
# 0  2137.079844  4697.131077  9931.208257     1
# label
# 2    84
# 1    42
# Name: count, dtype: int64

# %%
assign_target_column(df_lsvt, "label", ['1'])
fill_na(df_lsvt)
delete_corr_columns(df_lsvt)
check_feature_sample_ratio(df_lsvt)
# Out:
# Unique values of label column ['1', '2']
# Categories (2, object): ['1' < '2']
# target
# 0    84
# 1    42
# Name: count, dtype: int64
# deleted features: ['V2', 'V3', 'V5', 'V7', 'V10', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V20', 'V21', 'V22', 'V29', 'V30', 'V32', 'V33', 'V35', 'V36', 'V38', 'V39', 'V41', 'V43', 'V44', 'V45', 'V46', 'V47', 'V48', 'V50', 'V55', 'V61', 'V63', 'V70', 'V72', 'V73', 'V76', 'V79', 'V82', 'V126', 'V127', 'V130', 'V131', 'V132', 'V133', 'V134', 'V135', 'V136', 'V137', 'V138', 'V139', 'V141', 'V142', 'V143', 'V144', 'V145', 'V146', 'V147', 'V148', 'V149', 'V151', 'V152', 'V153', 'V160', 'V161', 'V162', 'V163', 'V164', 'V165', 'V166', 'V167', 'V168', 'V169', 'V170', 'V171', 'V172', 'V173', 'V174', 'V175', 'V176', 'V177', 'V178', 'V179', 'V181', 'V182', 'V183', 'V184', 'V185', 'V186', 'V187', 'V188', 'V189', 'V191', 'V192', 'V193', 'V194', 'V195', 'V196', 'V197', 'V198', 'V199', 'V200', 'V201', 'V202', 'V203', 'V204', 'V205', 'V206', 'V207', 'V208', 'V209', 'V210', 'V211', 'V212', 'V213', 'V214', 'V215', 'V216', 'V217', 'V218', 'V219', 'V220', 'V221', 'V222', 'V223', 'V224', 'V225', 'V226', 'V227', 'V228', 'V229', 'V230', 'V231', 'V232', 'V233', 'V236', 'V237', 'V238', 'V239', 'V240', 'V241', 'V242', 'V243', 'V244', 'V251', 'V252', 'V253', 'V254', 'V255', 'V256', 'V257', 'V258', 'V259', 'V260', 'V261', 'V262', 'V263', 'V264', 'V265', 'V266', 'V267', 'V268', 'V269', 'V270', 'V271', 'V272', 'V273', 'V274', 'V275', 'V276', 'V277', 'V278', 'V279', 'V280', 'V281', 'V282', 'V283', 'V284', 'V285', 'V286', 'V287', 'V288', 'V289', 'V290', 'V291', 'V292', 'V293', 'V294', 'V295', 'V296', 'V297', 'V298', 'V299', 'V300', 'V301', 'V302', 'V303', 'V304', 'V305', 'V306', 'V307', 'V308', 'V309', 'V310']
# Shape after deletion (126, 107)
# The number of features is enough: True, number of features: 107

# %%
X = df_lsvt.drop(columns=['target'])
y = df_lsvt['target']
X = StandardScaler().fit_transform(X)
plot_our_history(X, y.values, epochs=100, lam=1e-3)
# Out:
# Accuracy:
# Accelerated CD: 1.000
# CD: 1.000
# FISTA: 1.000
# Subgradient: 0.881
# F1 score:
# Accelerated CD: 1.000
# CD: 1.000
# FISTA: 1.000
# Subgradient: 0.842

# %% [markdown]
# # Syntetic

# %%
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

configs = [
    dict(n_samples=1000, n_features=500,  n_informative=20,  n_redundant=50,
         flip_y=0.15, class_sep=0.5, random_state=0),
    dict(n_samples=1500, n_features=1000, n_informative=30,  n_redundant=300,
         flip_y=0.25, class_sep=0.3, random_state=1),
    dict(n_samples= 800, n_features=400,  n_informative=10,  n_redundant=50,
         n_clusters_per_class=2, flip_y=0.30, class_sep=0.2, random_state=2),
    dict(n_samples= 450, n_features=400,  n_informative=10,  n_redundant=50,
         n_clusters_per_class=2, flip_y=0.40, class_sep=0.1, random_state=3)
]
from sklearn.datasets import make_classification

for idx, cfg in enumerate(configs):
    X, y = make_classification(**cfg)
    X = StandardScaler().fit_transform(X); y = y.astype(float)
    plot_our_history(X, y, epochs=150, lam=1e-3)
# Out:
# Accuracy:
# Accelerated CD: 0.873
# CD: 0.875
# FISTA: 0.873
# Subgradient: 0.822
# F1 score:
# Accelerated CD: 0.871
# CD: 0.873
# FISTA: 0.871
# Subgradient: 0.821
# Accuracy:
# Accelerated CD: 0.840
# CD: 0.841
# FISTA: 0.841
# Subgradient: 0.810
# F1 score:
# Accelerated CD: 0.838
# CD: 0.840
# FISTA: 0.839
# Subgradient: 0.809
# Accuracy:
# Accelerated CD: 0.843
# CD: 0.844
# FISTA: 0.843
# Subgradient: 0.782
# F1 score:
# Accelerated CD: 0.841
# CD: 0.842
# FISTA: 0.841
# Subgradient: 0.777
# Accuracy:
# Accelerated CD: 1.000
# CD: 1.000
# FISTA: 1.000
# Subgradient: 0.902
# F1 score:
# Accelerated CD: 1.000
# CD: 1.000
# FISTA: 1.000
# Subgradient: 0.899
